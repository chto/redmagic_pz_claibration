# %%
import fitsio
import numpy as np 
import matplotlib.pyplot as plt
# %load_ext autoreload
from tqdm import tqdm
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cat_all = {}
cat_all['highdense'] = fitsio.read("../data/newbuzzard_final/redmagic_3a/buzzard-3_1.9.2+1-6a_run_redmapper_v6.4.22_redmagic_highdens_0.5-10.fit")
cat_all['highlum'] = fitsio.read("../data/newbuzzard_final/redmagic_3a/buzzard-3_1.9.2+1-6a_run_redmapper_v6.4.22_redmagic_highlum_1.0-04.fit")
cat_all['higherlum'] = fitsio.read("../data/newbuzzard_final/redmagic_3a/buzzard-3_1.9.2+1-6a_run_redmapper_v6.4.22_redmagic_higherlum_1.5-01.fit")

# %%
mask = np.random.randint(0,len(cat), 10000)
plt.plot(cat['ZREDMAGIC'][mask],cat['ZSPEC'][mask],  "+")
plt.plot(cat['ZSPEC'][mask],cat['ZSPEC'][mask])

# %%
mask = np.abs(cat['ZREDMAGIC']-0.35)<0.0005
plt.plot(cat['MODEL_MAG'][mask,0], cat['MODEL_MAG'][mask,0]-cat['MODEL_MAG'][mask,1], "+")

# %%
for ind, z in enumerate(np.linspace(0.15,0.9,20)):
    plt.figure()
    plt.title("$z_{{redmagic}}$={0}".format(z))
    if z<0.65:
        cat = cat_all['highdense']
    elif z<0.8:
        cat = cat_all['highlum']
    else:
        cat = cat_all['higherlum']
    mask = np.abs(cat['ZREDMAGIC']-z)<0.01
    bins=np.linspace(0.1,1.1, 100)
    plt.hist(cat['ZSPEC'][mask], bins=bins, normed=True)
    plt.xlabel("ZSPEC")
    plt.ylabel("normed hist")
    #plt.yscale('log')
    plt.axvline(z, c="r")
    #plt.savefig("./figures/redmagic_ind_{0}_lin.png".format(ind), dpi=200)
    #plt.clf()
# Out:
# /home/groups/kipac/chto/anaconda2/envs/newenv3/lib/python3.7/site-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   if sys.path[0] == '':
# /home/groups/kipac/chto/anaconda2/envs/newenv3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
for ind, z in enumerate(np.linspace(0.15,0.9,66)):
    plt.figure()
    plt.title("$z_{{redmagic}}$={0}".format(z))
    if z<0.65:
        cat = cat_all['highdense']
    elif z<0.8:
        cat = cat_all['highlum']
    else:
        cat = cat_all['higherlum']
    mask = np.abs(cat['ZREDMAGIC']-z)<0.01
    bins=np.linspace(0.1,1.1, 100)
    plt.hist(cat['ZSPEC'][mask], bins=bins, normed=True)
    plt.xlabel("ZSPEC")
    plt.ylabel("normed hist")
    plt.yscale('log')
    plt.axvline(z, c="r")
    plt.savefig("./figures/redmagic_ind_{0}_log.png".format(ind), dpi=200)
    plt.clf()
# Out:
# /home/groups/kipac/chto/anaconda2/envs/newenv3/lib/python3.7/site-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   if sys.path[0] == '':
# /home/groups/kipac/chto/anaconda2/envs/newenv3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
for z in np.linspace(0.3,0.4,11):
    plt.figure()
    plt.title("z={0}".format(z))
    mask = np.abs(cat['ZSPEC']-z)<0.0005
    bins=np.linspace(0.2,0.6,50)
    plt.hist(cat['ZREDMAGIC'][mask], bins=bins)
    plt.axvline(z, c="r")

# %%
from scipy.stats import norm, entropy
from scipy.optimize import curve_fit
from scipy.optimize import minimize, rosen, rosen_der
import emcee
def fit_function(x, param):
    m1, sig1, m2, sig2, f1 = param
    y= f1*multivariate_normal.pdf(x,m1,sig1**2)+(1-f1)*multivariate_normal.pdf(x, m2, sig2**2)
    return y
def loglikelihood(param, x, y, err, func):
    m1, sig1, m2, sig2, f1 = param
    #print(param)
    if m2<m1:
        return -np.inf
    if (f1>1) or (f1<0):
        return -np.inf
    if (m1<0) or (m2<0) or (sig1<0) or (sig2<0):
        return -np.inf
    if (sig1>1) or (sig2>1):
        return -np.inf
    #print(param, np.nansum(-1*((y-func(x, param))**2/err**2)))
    #return -1*np.nansum(((y-func(x, param))**2/err**2))
    return -1*entropy(y, func(x, param)) #-1*KL divergence
def negativeloglikelihood(param, x, y, err, func):
    return -1*loglikelihood(param, x, y, err, func)

# %%
for ind, z in enumerate([0.22]):#,0.23,0.24,0.32,0.47,0.5, 0.80]):
    #Create the data
    if z<0.65:
        cat = cat_all['highdense']
    elif z<0.8:
        cat = cat_all['highlum']
    else:
        cat = cat_all['higherlum']
    mask = np.abs(cat['ZREDMAGIC']-z)<0.01
    bins=np.linspace(0.1,1.1, 200)
    bins_center = 0.5*(bins[1:]+bins[:-1])
    histogram, _ = np.histogram(cat['ZSPEC'][mask], bins=bins, normed=True)
    histogram_test, _ = np.histogram(cat['ZSPEC'][mask], bins=bins, normed=False)
    hist_err = histogram/np.sqrt(histogram_test)    
    #Fitting 
    x0=(bins_center[np.argmax(histogram)], 0.05,bins_center[np.argmax(histogram)]+0.2,0.001,0.7)
    #(0.21987423, 0.01032247, 0.3, 0.03, 0.9)
    #
    res = minimize(negativeloglikelihood, x0, method='Nelder-Mead', tol=1e-6, args=(bins_center, histogram, hist_err, fit_function))
    bestfit_param = res.x
    #print(res)
    #nwalker = 10
    #nparam = 5
    #sampler = emcee.EnsembleSampler(nwalker, nparam, loglikelihood, args=(bins_center, histogram, hist_err, fit_function))
    #pos = x0 + 1e-2*np.random.randn(nwalker, nparam)
    #sampler.run_mcmc(pos, 5000, progress=True);
    #bestfit_param = sampler.flatchain[np.argmax(sampler.flatlnprobability)]
    #Plotting 
    plt.figure()
    plt.title("$z_{{redmagic}}$={0}".format(z))
    plt.errorbar(bins_center, histogram, yerr=hist_err, fmt="o", markersize='1')
    plt.plot(bins_center, fit_function( bins_center, bestfit_param), lw=1.5)
    plt.xlabel("ZSPEC")
    plt.ylabel("normed hist")
    plt.axvline(z, c="r")
# Out:
# /home/groups/kipac/chto/anaconda2/envs/newenv3/lib/python3.7/site-packages/ipykernel_launcher.py:12: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.
#   if sys.path[0] == '':
# /home/groups/kipac/chto/anaconda2/envs/newenv3/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: Passing normed=False is deprecated, and has no effect. Consider passing the density argument instead.
#   del sys.path[0]

# %%
plt.figure()
bestfit_param = [0.21987423, 0.01032247, 0.3, 0.03, 0.9]
print(loglikelihood(bestfit_param,bins_center, histogram, hist_err, fit_function))
plt.title("$z_{{redmagic}}$={0}".format(z))
plt.errorbar(bins_center, histogram, yerr=hist_err, fmt="o", markersize='1')
plt.plot(bins_center, fit_function( bins_center, bestfit_param), lw=1.5)
plt.axvline(0.3)
plt.xlabel("ZSPEC")
plt.ylabel("normed hist")
plt.axvline(z, c="r")
# Out:
# -0.05351077598234639

# %%
fig, axes = plt.subplots(nparam, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = ['m1', 's1', 'm2', 's2', 'f', 'logp']
for i in range(nparam):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number");

# %% [markdown]
# # GMM+EM

# %%
from scipy.stats import multivariate_normal
def run_em(x, w, phi, mu, sigma, silent=False):
    """Problem 3(d): EM Algorithm (unsupervised).
    Args:
        x: Design matrix of shape (m, n).
        w: Initial weight matrix of shape (m, k).
        phi: Initial mixture prior, of shape (k,).
        mu: Initial cluster means, list of k arrays of shape (n,).
        sigma: Initial cluster covariances, list of k arrays of shape (n, n).

    Returns:
        Updated weight matrix of shape (m, k) resulting from EM algorithm.
        More specifically, w[i, j] should contain the probability of
        example x^(i) belonging to the j-th Gaussian in the mixture.
    """
    # No need to change any of these parameters
    eps = 1e-1  # Convergence threshold
    max_iter = 100

    # Stop when the absolute change in log-likelihood is < eps
    # See below for explanation of the convergence criterion
    it = 0
    ll = prev_ll = None
    while it < max_iter and (prev_ll is None or np.abs(ll - prev_ll) >= eps):
        #pass  # Just a placeholder for the starter code
        # *** START CODE HERE
        # (1) E-step: Update your estimates in w
        # (2) M-step: Update the model parameters phi, mu, and sigma
        # (3) Compute the log-likelihood of the data to check for convergence.
        # By log-likelihood, we mean `ll = sum_x[log(sum_z[p(x|z) * p(z)])]`.
        # We define convergence by the first iteration where abs(ll - prev_ll) < eps.
        # Hint: For debugging, recall part (a). We showed that ll should be monotonically increasing.
        m, n = x.shape
        m, k = w.shape
#E step:
        if ll is None:
            for i in range(k):
                p_given_z = np.array([multivariate_normal.pdf(x[j], mu[i], sigma[i]) for j in range(m)]) 
                w[:, i] = phi[i]*p_given_z
            norm = np.sum(w, axis=1).reshape(-1,1)
            w = w/norm 
        else:
            w = w
        #M step :
        phi = np.mean(w, axis=0) 
        mu = w.T.dot(x)/np.sum(w, axis=0).reshape(-1,1)
        assert (mu.shape==(k,n))
        for i in range(k):
            sigma[i] = np.dot((w[:,i].reshape(-1,1)*(x-mu[i])).T, (x-mu[i]))/np.sum(w[:,i])
        assert (sigma[0].shape == (n,n))

        for i in range(k):
            #if i==0:
                #from scipy.stats import multivariate_normal
                #print(multivariate_normal.pdf(x[0], mean=mu[i], cov=sigma[i]))
                #print(gaussian(x[0], mu[i], sigma[i]))
            p_given_z = np.array([multivariate_normal.pdf(x[j], mu[i], sigma[i]) for j in range(m)]) 
            w[:, i] = phi[i]*p_given_z
        norm = np.sum(w, axis=1).reshape(-1,1)
        w = w/norm 
        prev_ll = ll
        ll = np.sum(np.log(norm))
        if not silent:
            print("iteration, log likelihood", it, ll)
        if prev_ll is not None:
            assert (ll>=prev_ll)
        it += 1
        # *** END CODE HERE ***
        #
    f1 = np.mean(w,axis=0)
    return w, f1,  mu.squeeze(), np.sqrt(np.array(sigma).squeeze())

# %%
def fit_function(x, param):
    f_in, mu, sigma,ngaussian = param
    y = 0
    for i in range(ngaussian):
        y += f_in[i]*multivariate_normal.pdf(x, mu[i], sigma[i]**2)
    return y
def do_em(x):
    ngaussian = 2
    w = np.ones((x.shape[0], ngaussian))/float(ngaussian)
    phi = np.ones(ngaussian)
    mu = []
    for _ in range(ngaussian):
        mu.append([np.random.uniform(x[:,i].min(), x[:,i].max()) for i in range(x.shape[1])])
    sigma = [np.cov(x, rowvar=False) for _ in range(ngaussian)]
    w, f1, mu, sigma = run_em(x, w, phi, mu, sigma, silent=True)
    return f1, mu, sigma, ngaussian

# %%
z = 0.22
cat = cat_all['highdense']
mask = np.abs(cat['ZREDMAGIC']-z)<0.01
bins=np.linspace(0.1,1.1, 200)
bins_center = 0.5*(bins[1:]+bins[:-1])
x = cat['ZSPEC'][mask].reshape(-1,1)
param = do_em(x)

# %%
param
# Out:
# (array([0.83830788, 0.16169212]),
#  array([0.21970656, 0.28732532]),
#  array([0.01064445, 0.04338398]),
#  2)

# %%
bins_center = 0.5*(bins[1:]+bins[:-1])
histogram, _ = np.histogram(x, bins=bins, normed=True)
plt.figure()
plt.title("$z_{{redmagic}}$={0}".format(z))
plt.errorbar(bins_center, histogram, yerr=hist_err, fmt="o", markersize='1')
plt.plot(bins_center, fit_function(bins_center.reshape(-1,1), param))

#plt.plot(bins_center, fit_function( bins_center, bestfit_param), lw=1.5)
plt.xlabel("ZSPEC")
plt.ylabel("normed hist")
plt.axvline(z, c="r")
# Out:
# /home/groups/kipac/chto/anaconda2/envs/newenv3/lib/python3.7/site-packages/ipykernel_launcher.py:2: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.

# %%
for ind, z in enumerate(tqdm([0.22, 0.23,0.24,0.32,0.47,0.5, 0.80])):
    #Create the data
    if z<0.65:
        cat = cat_all['highdense']
    elif z<0.8:
        cat = cat_all['highlum']
    else:
        cat = cat_all['higherlum']
    mask = np.abs(cat['ZREDMAGIC']-z)<0.01
    bins=np.linspace(0.1,1.1, 200)
    bins_center = 0.5*(bins[1:]+bins[:-1])
    histogram, _ = np.histogram(cat['ZSPEC'][mask], bins=bins, normed=True)
    histogram_test, _ = np.histogram(cat['ZSPEC'][mask], bins=bins, normed=False)
    hist_err = histogram/np.sqrt(histogram_test)    
    x = cat['ZSPEC'][mask].reshape(-1,1)
    param = do_em(x)
    
    plt.figure()
    plt.title("$z_{{redmagic}}$={0}".format(z))
    plt.errorbar(bins_center, histogram, yerr=hist_err, fmt="o", markersize='1')
    plt.plot(bins_center, fit_function(bins_center.reshape(-1,1), param), lw=1.5)
    plt.xlabel("ZSPEC")
    plt.ylabel("normed hist")
    plt.axvline(z, c="r")
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]/home/groups/kipac/chto/anaconda2/envs/newenv3/lib/python3.7/site-packages/ipykernel_launcher.py:12: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.
#   if sys.path[0] == '':
# /home/groups/kipac/chto/anaconda2/envs/newenv3/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: Passing normed=False is deprecated, and has no effect. Consider passing the density argument instead.
#   del sys.path[0]
# /home/groups/kipac/chto/anaconda2/envs/newenv3/lib/python3.7/site-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in true_divide
#
# 100%|██████████| 7/7 [18:43<00:00, 198.73s/it]
